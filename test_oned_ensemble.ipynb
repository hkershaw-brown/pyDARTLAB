# %%
import matplotlib.pyplot as plt
import dartlabplot as dlp
import matplotlib.gridspec as gridspec

# %matplotlib widget

# Create figure
fig = plt.figure(figsize=(10, 8))
fig.canvas.header_visible = False

# Define GridSpec
gs = gridspec.GridSpec(4, 3, figure=fig)



# Create subplots of varying sizes and shapes
ax1 = fig.add_subplot(gs[0:3, 0:2]) 
ax1.set_xlim(-2, 4)
ax1.set_ylim(-0.4, 1)

mu = 1
sigma = 1

plotter = dlp.OnedEnsemble(fig, ax1, mu, sigma,[-2, 4], [-0.4, 1])

plotter.add_filter_options([0.65, 0.68, 0.2, 0.2])
plotter.add_update_button([0.65, 0.3, 0.2, 0.1])
plotter.add_mu_observation_textbox([0.75, 0.5, 0.1, 0.03])
plotter.add_sigma_observation_textbox([0.75, 0.45, 0.1, 0.03])
plotter.add_inflation_slider([0.70, 0.55, 0.12, 0.03])
plotter.add_inflation_toggle([0.65, 0.60, 0.15, 0.05])
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
# Clicked at x=-0.16720301832271778
# Clicked at x=0.4430022602696577
# Clicked at x=0.8139113511787484
# Clicked at x=-0.9209860095250639
# Clicked at x=-1.0525989127508706
# Clicked at x=1.6035887705335874
# Clicked at x=2.3813013805042624
# Clicked at x=2.8598937558708313
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:293, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     291 guiEvent = event.get('guiEvent')
#     292 if e_type in ['button_press', 'button_release']:
# --> 293     MouseEvent(e_type + '_event', self, x, y, button,
#     294                modifiers=modifiers, guiEvent=guiEvent)._process()
#     295 elif e_type == 'dblclick':
#     296     MouseEvent('button_press_event', self, x, y, button, dblclick=True,
#     297                modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/widgets.py:238, in Button._release(self, event)
#     236 event.canvas.release_mouse(self.ax)
#     237 if self.eventson and self.ax.contains(event)[0]:
# --> 238     self._observers.process('clicked', event)
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/widgets.py:259, in Button.on_clicked.<locals>.<lambda>(event)
#     253 def on_clicked(self, func):
#     254     """
#     255     Connect the callback function *func* to button click events.
#     256
#     257     Returns a connection id, which can be used to disconnect the callback.
#     258     """
# --> 259     return self._observers.connect('clicked', lambda event: func(event))
#
# File ~/DART/Projects/pyDART_LAB/dartlabplot.py:359, in OnedEnsemble.update_ensemble(self, event)
#     356 z_plot = [element - 0.1 for i, element in enumerate(zeros_array)]
#     357 self.ax1.plot(updated_x, z_plot, 'b*')
# --> 359 if self.inflation_enabled:
#     360     # Apply inflation to the ensemble
#     361     inf_x = (x_list - x_list.mean())* math.sqrt(self.inflation_factor) + x_list.mean()
#     363 # plot increment lines
#
# AttributeError: 'OnedEnsemble' object has no attribute 'inflation_enabled'
# Inflation enabled: True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:293, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     291 guiEvent = event.get('guiEvent')
#     292 if e_type in ['button_press', 'button_release']:
# --> 293     MouseEvent(e_type + '_event', self, x, y, button,
#     294                modifiers=modifiers, guiEvent=guiEvent)._process()
#     295 elif e_type == 'dblclick':
#     296     MouseEvent('button_press_event', self, x, y, button, dblclick=True,
#     297                modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/widgets.py:238, in Button._release(self, event)
#     236 event.canvas.release_mouse(self.ax)
#     237 if self.eventson and self.ax.contains(event)[0]:
# --> 238     self._observers.process('clicked', event)
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File ~/DART/Projects/pyDART_LAB/pylab/lib/python3.9/site-packages/matplotlib/widgets.py:259, in Button.on_clicked.<locals>.<lambda>(event)
#     253 def on_clicked(self, func):
#     254     """
#     255     Connect the callback function *func* to button click events.
#     256
#     257     Returns a connection id, which can be used to disconnect the callback.
#     258     """
# --> 259     return self._observers.connect('clicked', lambda event: func(event))
#
# File ~/DART/Projects/pyDART_LAB/dartlabplot.py:361, in OnedEnsemble.update_ensemble(self, event)
#     357 self.ax1.plot(updated_x, z_plot, 'b*')
#     359 if self.inflation_enabled:
#     360     # Apply inflation to the ensemble
# --> 361     inf_x = (x_list - x_list.mean())* math.sqrt(self.inflation_factor) + x_list.mean()
#     363 # plot increment lines
#     364 for i, _ in enumerate(updated_x):
#
# AttributeError: 'OnedEnsemble' object has no attribute 'inflation_factor'
